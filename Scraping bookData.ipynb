# %%
import pandas as pd

# %%
data = pd.read_csv("books.csv")
# Out:
#      Unnamed: 0                                              Title  \
# 1             1                                 Tipping the Velvet
# 2             2                                         Soumission
# 3             3                                      Sharp Objects
# 4             4              Sapiens: A Brief History of Humankind
# 5             5                                    The Requiem Red
# ..          ...                                                ...
# 995         995  Alice in Wonderland (Alice's Adventures in Won...
# 996         996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)
# 997         997  A Spy's Devotion (The Regency Spies of London #1)
# 998         998                1st to Die (Women's Murder Club #1)
# 999         999                 1,000 Places to See Before You Die
#
#                                                   Link  Price     Stock
# 1                    tipping-the-velvet_999/index.html  53.74  In stock
# ...

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

data = []
current_page = 1
proceed = True

while(proceed):
    print("Scraping Current page is "+str(current_page))

    url = "https://books.toscrape.com/catalogue/page-"+str(current_page)+".html"

    page = requests.get(url)

    soap = BeautifulSoup(page.text, 'html.parser')
    
    if soap.title.text == "404 Not Found":
        proceed = False
    else:
        all_books = soap.find_all('li', class_="col-xs-6 col-sm-4 col-md-3 col-lg-3")
        
        for book in all_books:
            item = {}

            item['Title'] = book.find("img").attrs['alt']

            item['Link'] = book.find('a').attrs['href']

            item['Price'] = book.find('p',class_= "price_color").text[2:]

            item['Stock'] = book.find('p', class_="instock availability").text.strip()
            
            data.append(item)

    current_page +=1
        
df = pd.DataFrame(data)
# df.to_csv("books.csv",index=False)
# Out:
# Scraping Current page is 1
# Scraping Current page is 2
# Scraping Current page is 3
# Scraping Current page is 4
# Scraping Current page is 5
# Scraping Current page is 6
# Scraping Current page is 7
# Scraping Current page is 8
# Scraping Current page is 9
# Scraping Current page is 10
# Scraping Current page is 11
# Scraping Current page is 12
# Scraping Current page is 13
# Scraping Current page is 14
# Scraping Current page is 15
# Scraping Current page is 16
# Scraping Current page is 17
# Scraping Current page is 18
# Scraping Current page is 19
# Scraping Current page is 20
# Scraping Current page is 21
# Scraping Current page is 22
# Scraping Current page is 23
# Scraping Current page is 24
# Scraping Current page is 25
# Scraping Current page is 26
# Scraping Current page is 27
# Scraping Current page is 28
# Scraping Current page is 29
# Scraping Current page is 30
# Scraping Current page is 31
# Scraping Current page is 32
# Scraping Current page is 33
# ...

# %%
df.head()
# Out:
#                                    Title  \
# 0                   A Light in the Attic
# 1                     Tipping the Velvet
# 2                             Soumission
# 3                          Sharp Objects
# 4  Sapiens: A Brief History of Humankind
#
#                                                 Link  Price     Stock  \
# 0               a-light-in-the-attic_1000/index.html  51.77  In stock
# 1                  tipping-the-velvet_999/index.html  53.74  In stock
# 2                          soumission_998/index.html  50.10  In stock
# 3                       sharp-objects_997/index.html  47.82  In stock
# 4  sapiens-a-brief-history-of-humankind_996/index...  54.23  In stock
#
#                                            Book_link
# 0  https://books.toscrape.com/catalogue/a-light-i...
# 1  https://books.toscrape.com/catalogue/tipping-t...
# 2  https://books.toscrape.com/catalogue/soumissio...
# 3  https://books.toscrape.com/catalogue/sharp-obj...
# ...

# %%
df['Link'] = "https://books.toscrape.com/catalogue/" + df['Link']

# %%
df['Link']
# Out:
# 0      https://books.toscrape.com/catalogue/a-light-i...
# 1      https://books.toscrape.com/catalogue/tipping-t...
# 2      https://books.toscrape.com/catalogue/soumissio...
# 3      https://books.toscrape.com/catalogue/sharp-obj...
# 4      https://books.toscrape.com/catalogue/sapiens-a...
#                              ...
# 995    https://books.toscrape.com/catalogue/alice-in-...
# 996    https://books.toscrape.com/catalogue/ajin-demi...
# 997    https://books.toscrape.com/catalogue/a-spys-de...
# 998    https://books.toscrape.com/catalogue/1st-to-di...
# 999    https://books.toscrape.com/catalogue/1000-plac...
# Name: Link, Length: 1000, dtype: object

# %%
df.head()
# Out:
#                                    Title  \
# 0                   A Light in the Attic
# 1                     Tipping the Velvet
# 2                             Soumission
# 3                          Sharp Objects
# 4  Sapiens: A Brief History of Humankind
#
#                                                 Link  Price     Stock
# 0  https://books.toscrape.com/catalogue/a-light-i...  51.77  In stock
# 1  https://books.toscrape.com/catalogue/tipping-t...  53.74  In stock
# 2  https://books.toscrape.com/catalogue/soumissio...  50.10  In stock
# 3  https://books.toscrape.com/catalogue/sharp-obj...  47.82  In stock
# 4  https://books.toscrape.com/catalogue/sapiens-a...  54.23  In stock

# %%
df.to_csv(r'C:\Users\BP\Downloads\webScrapping\main_book.csv',index = False)
